# %%
# !pip install ultralytics
# Out:
# ...
#   Obtaining dependency information for ultralytics from https://files.pythonhosted.org/packages/e6/27/90daa13a80ece0e45f693bbce0413f24f7f42bb7d08e4fd4fdc45f10febd/ultralytics-8.0.208-py3-none-any.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.2/645.2 kB 32.2 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

model = YOLO('yolov8l-cls.pt')
results = model.train(
    data='/kaggle/input/hack-scfo/images',
    epochs=3
)
# Out:
# ...
# 100%|██████████| 71.7M/71.7M [00:00<00:00, 233MB/s]
# Ultralytics YOLOv8.0.208 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
# ...

# %%
model = YOLO('/kaggle/working/runs/classify/train/weights/best.pt')  # load a custom model

# Predict with the model
results = model('https://thegeorgiaclubhomes.com/wp-content/uploads/2018/12/img-04.jpg')
# Out:
# ...
# 100%|██████████| 42.1k/42.1k [00:00<00:00, 421kB/s]
# image 1/1 /kaggle/working/img-04.jpg: 224x224 golf 1.00, pick 0.00, sit 0.00, sword_exercise 0.00, handstand 0.00, 9.4ms
# Speed: 3.1ms preprocess, 9.4ms inference, 0.2ms postprocess per image at shape (1, 3, 224, 224)

# %%
# Predict with the model
results_video = model('https://assets.mixkit.co/videos/preview/mixkit-girl-doing-sit-ups-lying-on-the-floor-4591-large.mp4')
# Out:
# ...
# 100%|██████████| 3.70M/3.70M [00:00<00:00, 41.4MB/s]
#
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/372) /kaggle/working/mixkit-girl-doing-sit-ups-lying-on-the-floor-4591-large.mp4: 224x224 situp 1.00, sit 0.00, jump 0.00, shoot_ball 0.00, pushup 0.00, 7.0ms
# video 1/1 (2/372) /kaggle/working/mixkit-girl-doing-sit-ups-lying-on-the-floor-4591-large.mp4: 224x224 situp 1.00, sit 0.00, jump 0.00, shoot_ball 0.00, pushup 0.00, 6.9ms
# ...
