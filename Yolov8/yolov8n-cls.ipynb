# %%
import numpy as np
import pandas as pd
import os

# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

model = YOLO('yolov8n-cls.pt')
results = model.train(
    data='/kaggle/input/hack-scfo/images',
    epochs=3
)
# Out:
# ...
# 100%|██████████| 5.28M/5.28M [00:00<00:00, 267MB/s]
# Ultralytics YOLOv8.0.208 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
# ...

# %%
# Сохраните модель
torch.save(model.state_dict(), '/kaggle/working/model.pt')

# %%
model = YOLO('/kaggle/working/runs/classify/train/weights/best.pt')  # load a custom model

# Predict with the model
results = model('https://assets.mixkit.co/videos/preview/mixkit-man-doing-pull-ups-in-the-park-25248-large.mp4')
# Out:
# ...
# 100%|██████████| 6.78M/6.78M [00:01<00:00, 4.54MB/s]
#
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/563) /kaggle/working/mixkit-man-doing-pull-ups-in-the-park-25248-large.mp4: 224x224 pullup 0.76, jump 0.18, pick 0.03, sit 0.01, shoot_ball 0.01, 3.2ms
# video 1/1 (2/563) /kaggle/working/mixkit-man-doing-pull-ups-in-the-park-25248-large.mp4: 224x224 pullup 0.79, jump 0.18, sit 0.01, pick 0.01, shoot_ball 0.00, 3.1ms
# ...
